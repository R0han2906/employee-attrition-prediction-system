# %%
import pandas as pd  
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
plt.hist(df["NumCompaniesWorked"])
# Out:
# (array([197., 521., 146., 159., 139.,  63.,  70.,  74.,  49.,  52.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
df["Educatio"].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
for col in df.columns:
    if df[col].nunique() == 1:
        print(col)
# Out:
# EmployeeCount
# Over18
# StandardHours

# %%
df['EmployeeCount'].value_counts()
# Out:
# EmployeeCount
# 1    1470
# Name: count, dtype: int64

# %% [markdown]
# constant columns - EmployeeCount
#                    Over18
#                    StandardHours

# %%
cat_cols = df.select_dtypes(include='object').columns
num_cols = df.select_dtypes(exclude='object').columns
print(cat_cols)
print(num_cols)
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df["EmployeeNumber"]
# Out:
# 0          1
# 1          2
# 2          4
# 3          5
# 4          7
#         ...
# 1465    2061
# 1466    2062
# 1467    2064
# 1468    2065
# 1469    2068
# Name: EmployeeNumber, Length: 1470, dtype: int64

# %%
df["EmployeeNumber"].nunique()
# Out:
# 1470

# %%
df['MonthlyIncome']
# Out:
# 0       5993
# 1       5130
# 2       2090
# 3       2909
# 4       3468
#         ...
# 1465    2571
# 1466    9991
# 1467    6142
# 1468    5390
# 1469    4404
# Name: MonthlyIncome, Length: 1470, dtype: int64

# %%
df["MonthlyIncome"].describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
df["MonthlyIncome"].skew()
# Out:
# np.float64(1.3698166808390662)

# %%
df['MonthlyIncome'] = np.log1p(df['MonthlyIncome'])

# %%
df['MonthlyIncome']
# Out:
# 0       8.698514
# 1       8.543056
# 2       7.645398
# 3       7.975908
# 4       8.151622
#           ...
# 1465    7.852439
# 1466    9.209540
# 1467    8.723069
# 1468    8.592486
# 1469    8.390496
# Name: MonthlyIncome, Length: 1470, dtype: float64

# %%
df[num_cols]
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %%
df['DailyRate'].skew()
# Out:
# np.float64(-0.003518568352325854)

# %%
df['HourlyRate'].skew()
# Out:
# np.float64(-0.03231095290044942)

# %%
num_cols
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df[num_cols]
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %%
for col in num_cols:
    plt.figure(figsize=(10, 4))
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
df[cat_cols]
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
df['Over18'].value_counts()
# Out:
# Over18
# Y    1470
# Name: count, dtype: int64

# %%
df['BusinessTravel'].value_counts()
# Out:
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64

# %%
df['JobRole'].value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
EmployeeCount
Over18
StandardHours
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 EmployeeCount
#       2 Over18
#       3 StandardHours
#
# NameError: name 'EmployeeCount' is not defined

# %% [markdown]
# cleaning of the data
#
# 1️⃣ Drop constant + EmployeeNumber
# 2️⃣ Encode target
# 3️⃣ Separate X and y
# 4️⃣ Identify:
#
# Ordinal numeric
# Continuous numeric
# Nominal categorical

# %%
df.drop(['EmployeeCount','Over18','StandardHours','EmployeeNumber'],axis=1,inplace=True)

# %%
df["Attrition"] = df["Attrition"].map({"Yes": 1, "No": 0})

# %%
X = df.drop('Attrition',axis=1)
y = df['Attrition']

ordinal_cols = [
    'Education',
    'JobLevel',
    'EnvironmentSatisfaction',
    'JobSatisfaction',
    'RelationshipSatisfaction',
    'WorkLifeBalance',
    'PerformanceRating',
    'StockOptionLevel'
]

cont_cols = [
    'Age',
    'DailyRate',
    'DistanceFromHome',
    'HourlyRate',
    'MonthlyIncome',
    'MonthlyRate',
    'NumCompaniesWorked',
    'PercentSalaryHike',
    'TotalWorkingYears',
    'TrainingTimesLastYear',
    'YearsAtCompany',
    'YearsInCurrentRole',
    'YearsSinceLastPromotion',
    'YearsWithCurrManager'
]

nominal_cols = [
    'BusinessTravel',
    'Department',
    'EducationField',
    'Gender',
    'JobRole',
    'MaritalStatus',
    'OverTime'
]

# %%
ordinal_cols.append('JobInvolvement')

# %%
set(X.columns) - set(ordinal_cols+cont_cols+nominal_cols)
# Out:
# set()

# %%
print("Total Features:", X.shape[1])
print("Ordinal:", len(ordinal_cols))
print("Continuous:", len(cont_cols))
print("Nominal:", len(nominal_cols))
# Out:
# Total Features: 30
# Ordinal: 9
# Continuous: 14
# Nominal: 7

# %% [markdown]
# this is preprocessing  all different types of columns

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

preprocessor = ColumnTransformer(
    transformers=[
        ('continuous_trans', StandardScaler(), cont_cols),
        ('ordinal_trans', 'passthrough', ordinal_cols),
        ('nominal_trans', OneHotEncoder(handle_unknown='ignore'), nominal_cols)
    ]
)

# %% [markdown]
# model_training

# %%
# Scikit-Learn Models

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    RandomForestClassifier,
    ExtraTreesClassifier,
    GradientBoostingClassifier
)
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold, cross_val_score

# Stratified K-Fold
skf = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

models = {
    "Logistic Regression": LogisticRegression(class_weight='balanced', max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Extra Trees": ExtraTreesClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(),
    "CatBoost": CatBoostClassifier(verbose=0)
}
for name, model in models.items():
    pipeline = Pipeline([
        ('preprocessor',preprocessor),
        ('model',model)
    ])

    scores = cross_val_score(
        pipeline,
        X,y,
        cv=skf,
        scoring='roc_auc'
    )

    print(f"{name}")
    print(f"ROC-AUC Scores : {scores}")
    print(f"Mean ROC-AUC   : {np.mean(scores)}")
    print("-" * 50)
# Out:
# Logistic Regression
# ROC-AUC Scores : [0.81910569 0.83604336 0.84916875 0.85338961 0.78258248]
# Mean ROC-AUC   : 0.828057978098947
# --------------------------------------------------
# Decision Tree
# ROC-AUC Scores : [0.54623984 0.59425813 0.65100353 0.64088207 0.68141097]
# Mean ROC-AUC   : 0.6227589095438288
# --------------------------------------------------
# Random Forest
# ROC-AUC Scores : [0.76880081 0.77879404 0.837023   0.82440348 0.77969679]
# Mean ROC-AUC   : 0.7977436234759454
# --------------------------------------------------
# Extra Trees
# ROC-AUC Scores : [0.78167344 0.80661416 0.82229305 0.80696012 0.77685416]
# Mean ROC-AUC   : 0.7988789864290882
# --------------------------------------------------
# Gradient Boosting
# ROC-AUC Scores : [0.78836382 0.80191396 0.82651391 0.82591093 0.80515118]
# Mean ROC-AUC   : 0.8095707592768063
# --------------------------------------------------
# XGBoost
# ...

# %%
import sklearn 
print(sklearn.__version__)
# Out:
# 1.7.2

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold ,cross_val_score
from sklearn.pipeline import Pipeline

log_model = Pipeline([
    ('preprocessor',preprocessor),
    ('model',LogisticRegression(class_weight='balanced',max_iter=1000))
])

skf = StratifiedKFold(n_splits=5,shuffle=True,random_state=42)

scores = cross_val_score(
    log_model,
    X,
    y,
    cv=skf,
    scoring='roc_auc'   
)
print("ROC-AUC scores:", scores)
print("Mean ROC-AUC:", np.mean(scores))
# Out:
# ROC-AUC scores: [0.81910569 0.83604336 0.84916875 0.85338961 0.78258248]
# Mean ROC-AUC: 0.828057978098947

# %% [markdown]
# top three models

# %%
top_models = {
    "Logistic Regression": LogisticRegression(class_weight='balanced', max_iter=1000),
    "CatBoost": CatBoostClassifier(verbose=0),
    "Gradient Boosting": GradientBoostingClassifier()
}

# %%
for name, model in top_models.items():
    pipeline = Pipeline([
        ('preprocessor',preprocessor),
        ('model',model)
    ])

    scores = cross_val_score(
        pipeline,
        X,y,
        cv=skf,
        scoring='recall'
    )

    print(f"{name}")
    print(f"recall Scores : {scores}")
    print(f"Mean recall  : {np.mean(scores)}")
    print("-" * 50)
# Out:
# Logistic Regression
# recall Scores : [nan nan nan nan nan]
# Mean recall  : nan
# --------------------------------------------------
# CatBoost
# recall Scores : [nan nan nan nan nan]
# Mean recall  : nan
# --------------------------------------------------
# Gradient Boosting
# recall Scores : [nan nan nan nan nan]
# Mean recall  : nan
# --------------------------------------------------

# %% [markdown]
# top 2 models to work on

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
top_2_models = {
    "Logistic Regression": LogisticRegression(),
    "CatBoost": CatBoostClassifier(verbose=0), 
}

param_grid = {
    "Logistic Regression": {
        "model__C": [0.1, 1, 10],
        "model__penalty": ["l1", "l2"],
        "model__solver": ["liblinear"]
    },

    "CatBoost": {
        "model__iterations": [100, 300],
        "model__depth": [4, 6],
        "model__learning_rate": [0.01, 0.1]
    }
}

# %%
top_2_models = {
    "Logistic Regression": LogisticRegression(class_weight='balanced',max_iter=1000),
    "CatBoost": CatBoostClassifier(verbose=0), 
}

param_grid = {
    "Logistic Regression": {
        "model__C": [0.1, 1, 10],
        "model__penalty": ["l1", "l2"],
        "model__solver": ["liblinear"]
    },

    "CatBoost": {
        "model__iterations": [100, 300],
        "model__depth": [4, 6],
        "model__learning_rate": [0.01, 0.1]
    }
}

from sklearn.model_selection import GridSearchCV

for name,model in top_2_models.items():

    pipeline = Pipeline([
        ('preprocessor',preprocessor),
        ('model',model)
    ])

    grid = GridSearchCV(
        estimator=pipeline,
        cv=5,
        param_grid=param_grid[name],
        scoring='roc_auc'
    )

    grid.fit(X_train,y_train)
    print(name)
    print("Best Score :", grid.best_score_)
    print("Best Params:", grid.best_params_)
    print("-"*50)



# Logistic Regression
# Best Score : 0.8307592354212712
# Best Params: {'model__C': 1, 'model__penalty': 'l2', 'model__solver': 'liblinear'}
# --------------------------------------------------
# CatBoost
# Best Score : 0.8173314766689066
# Best Params: {'model__depth': 6, 'model__iterations': 300, 'model__learning_rate': 0.01}
# --------------------------------------------------
# Out:
# Logistic Regression
# Best Score : 0.8307592354212712
# Best Params: {'model__C': 1, 'model__penalty': 'l2', 'model__solver': 'liblinear'}
# --------------------------------------------------
# CatBoost
# Best Score : 0.8173314766689066
# Best Params: {'model__depth': 6, 'model__iterations': 300, 'model__learning_rate': 0.01}
# --------------------------------------------------

# %%
top_2_models = {
    "Logistic Regression": LogisticRegression(),
    "CatBoost": CatBoostClassifier(verbose=0), 
}

param_grid = {
    "Logistic Regression": {
        "model__C": [0.1, 1, 10],
        "model__penalty": ["l1", "l2"],
        "model__solver": ["liblinear"]
    },

    "CatBoost": {
        "model__iterations": [100, 300],
        "model__depth": [4, 6],
        "model__learning_rate": [0.01, 0.1]
    }
}
from sklearn.model_selection import GridSearchCV

for name,model in top_2_models.items():

    pipeline = Pipeline([
        ('preprocessor',preprocessor),
        ('model',model)
    ])

    grid = GridSearchCV(
        estimator=pipeline,
        cv=5,
        param_grid=param_grid[name],
        scoring='roc_auc'
    )

    grid.fit(X_train,y_train)
    print(name)
    print("Best Score :", grid.best_score_)
    print("Best Params:", grid.best_params_)
    print("-"*50)
# Out:
# Logistic Regression
# Best Score : 0.8396234587391413
# Best Params: {'model__C': 10, 'model__penalty': 'l2', 'model__solver': 'liblinear'}
# --------------------------------------------------
# CatBoost
# Best Score : 0.8173314766689066
# Best Params: {'model__depth': 6, 'model__iterations': 300, 'model__learning_rate': 0.01}
# --------------------------------------------------

# %% [markdown]
# final model training

# %%
from sklearn.pipeline import Pipeline
from sklearn.metrics import recall_score, roc_auc_score, classification_report, confusion_matrix

best_lr = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(C=10, penalty='l2', solver='liblinear'))
])

best_lr.fit(X_train, y_train)

y_pred = best_lr.predict(X_test)
y_prob = best_lr.predict_proba(X_test)[:, 1]

recall = recall_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_prob)

print(f"Recall   : {recall:.4f}")
print(f"ROC-AUC  : {roc_auc:.4f}")

print("\nClassification Report")
print(classification_report(y_test, y_pred))
# Out:
# Recall   : 0.3830
# ROC-AUC  : 0.8094
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.93       247
#            1       0.67      0.38      0.49        47
#
#     accuracy                           0.87       294
#    macro avg       0.78      0.67      0.71       294
# weighted avg       0.86      0.87      0.86       294

# %%
from sklearn.metrics import recall_score,precision_score

thresholds = np.arange(0.1,0.9,0.05)

for t in thresholds:
    y_pred_thres = (y_prob>=t).astype(int)
    recall = recall_score(y_test,y_pred_thres)
    precision = precision_score(y_test,y_pred_thres)
    print(f"Threshold: {t:.2f} | Recall: {recall:.3f} | Precision: {precision:.3f}")
# Out:
# Threshold: 0.10 | Recall: 0.745 | Precision: 0.321
# Threshold: 0.15 | Recall: 0.660 | Precision: 0.369
# Threshold: 0.20 | Recall: 0.617 | Precision: 0.439
# Threshold: 0.25 | Recall: 0.596 | Precision: 0.475
# Threshold: 0.30 | Recall: 0.532 | Precision: 0.510
# Threshold: 0.35 | Recall: 0.468 | Precision: 0.537
# Threshold: 0.40 | Recall: 0.447 | Precision: 0.618
# Threshold: 0.45 | Recall: 0.447 | Precision: 0.656
# Threshold: 0.50 | Recall: 0.383 | Precision: 0.667
# Threshold: 0.55 | Recall: 0.319 | Precision: 0.652
# Threshold: 0.60 | Recall: 0.298 | Precision: 0.824
# Threshold: 0.65 | Recall: 0.213 | Precision: 0.833
# Threshold: 0.70 | Recall: 0.191 | Precision: 0.900
# Threshold: 0.75 | Recall: 0.191 | Precision: 1.000
# Threshold: 0.80 | Recall: 0.149 | Precision: 1.000
# Threshold: 0.85 | Recall: 0.085 | Precision: 1.000

# %% [markdown]
# feature engineering -
# feature 1: PromotionGap = YearsSinceLastPromotion / (YearsAtCompany + 1)
# 1. Create New Feature
#         ↓
# 2. Update X
#         ↓
# 3. Train-Test Split
#         ↓
# 4. Update Column Lists (if needed)
#         ↓
# 5. Recreate Preprocessor
#         ↓
# 6. Recreate Pipeline
#         ↓
# 7. Run GridSearchCV
#         ↓
# 8. Train Best Model
#         ↓
# 9. Evaluate on Test Set

# %%
df['PromotionGap'] = df['YearsSinceLastPromotion'] / (df['YearsAtCompany'] + 1)

# %%
cont_cols_updated = cont_cols.copy()
cont_cols_updated.append('PromotionGap')

# %%
X = df.drop(columns='Attrition')
y = df['Attrition']

# %%
X.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'PromotionGap'],
#       dtype='object')

# %%
cont_cols_updated
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'HourlyRate',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager',
#  'PromotionGap']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

preprocessor = ColumnTransformer(
    transformers=[
        ('cont', StandardScaler(), cont_cols_updated),
        ('ord', 'passthrough', ordinal_cols),
        ('nom', OneHotEncoder(handle_unknown='ignore'), nominal_cols)
    ]
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(max_iter=1000, solver='liblinear'))
])

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'model__C': [0.01, 0.1, 1, 10],
    'model__penalty': ['l1', 'l2']
}

grid = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1
)

grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('cont',
#                                                                          StandardScaler(),
#                                                                          ['Age',
#                                                                           'DailyRate',
#                                                                           'DistanceFromHome',
#                                                                           'HourlyRate',
#                                                                           'MonthlyIncome',
#                                                                           'MonthlyRate',
#                                                                           'NumCompaniesWorked',
#                                                                           'PercentSalaryHike',
# ...

# %%
best_model = grid.best_estimator_

print("Best Parameters:")
print(grid.best_params_)

print("\nBest CV ROC-AUC:")
print(grid.best_score_)
# Out:
# Best Parameters:
# {'model__C': 1, 'model__penalty': 'l2'}
#
# Best CV ROC-AUC:
# 0.8398355718553422

# %%
from sklearn.metrics import (
    recall_score,
    roc_auc_score,
    classification_report,
    confusion_matrix
)

y_pred = best_model.predict(X_test)
y_prob = best_model.predict_proba(X_test)[:, 1]

print("\n===== Test Metrics =====")
print(f"Test ROC-AUC : {roc_auc_score(y_test, y_prob):.4f}")
print(f"Test Recall  : {recall_score(y_test, y_pred):.4f}")

print("\nClassification Report")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix")
print(confusion_matrix(y_test, y_pred))
# Out:
# ===== Test Metrics =====
# Test ROC-AUC : 0.8144
# Test Recall  : 0.3404
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.92       247
#            1       0.67      0.34      0.45        47
#
#     accuracy                           0.87       294
#    macro avg       0.78      0.65      0.69       294
# weighted avg       0.85      0.87      0.85       294
#
#
# Confusion Matrix
# [[239   8]
#  [ 31  16]]

# %% [markdown]
# ✅ Keep baseline feature set (no PromotionGap)
# ✅ Use original preprocessing
# ✅ Tune:
#
# C
# l1_ratio
# ✅ scoring='roc_auc'
#
#
# this is switch model class process in which we introduce elasticnet

# %%
# ==========================================
# STEP 1: Remove PromotionGap (if it exists)
# ==========================================

if 'PromotionGap' in df.columns:
    df = df.drop(columns='PromotionGap')

# Remove from numerical columns if present
if 'PromotionGap' in cont_cols_updated:
    cont_cols_updated.remove('PromotionGap')

# ==========================================
# STEP 2: Define Features & Target
# ==========================================

X = df.drop(columns='Attrition')
y = df['Attrition']

# ==========================================
# STEP 3: Train-Test Split
# ==========================================

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# ==========================================
# STEP 4: Preprocessor
# ==========================================

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder

preprocessor = ColumnTransformer(
    transformers=[
        ('cont', StandardScaler(), cont_cols),
        ('ord', 'passthrough', ordinal_cols),
        ('nom', OneHotEncoder(handle_unknown='ignore'), nominal_cols)
    ]
)

# ==========================================
# STEP 5: Pipeline
# ==========================================

from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(
        penalty='elasticnet',
        solver='saga',
        max_iter=5000
    ))
])

# ==========================================
# STEP 6: Parameter Grid
# ==========================================

param_grid = {
    'model__C': [0.01, 0.1, 1, 10, 100],
    'model__l1_ratio': [0.0, 0.25, 0.5, 0.75, 1.0]
}

# %%
from sklearn.model_selection import GridSearchCV

grid = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1
)

grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('cont',
#                                                                          StandardScaler(),
#                                                                          ['Age',
#                                                                           'DailyRate',
#                                                                           'DistanceFromHome',
#                                                                           'HourlyRate',
#                                                                           'MonthlyIncome',
#                                                                           'MonthlyRate',
#                                                                           'NumCompaniesWorked',
#                                                                           'PercentSalaryHike',
# ...

# %%
best_model = grid.best_estimator_

print("Best Parameters:")
print(grid.best_params_)

print("\nBest CV ROC-AUC:")
print(grid.best_score_)

# ==========================================
# STEP 9: Test Set Evaluation
# ==========================================

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report,
    confusion_matrix
)

y_pred = best_model.predict(X_test)
y_prob = best_model.predict_proba(X_test)[:, 1]

print("\n===== Test Set Metrics =====")
print(f"Accuracy : {accuracy_score(y_test, y_pred):.4f}")
print(f"Precision: {precision_score(y_test, y_pred):.4f}")
print(f"Recall   : {recall_score(y_test, y_pred):.4f}")
print(f"F1 Score : {f1_score(y_test, y_pred):.4f}")
print(f"ROC-AUC  : {roc_auc_score(y_test, y_prob):.4f}")

print("\nClassification Report")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix")
print(confusion_matrix(y_test, y_pred))
# Out:
# Best Parameters:
# {'model__C': 1, 'model__l1_ratio': 0.75}
#
# Best CV ROC-AUC:
# 0.8399186899721229
#
# ===== Test Set Metrics =====
# Accuracy : 0.8776
# Precision: 0.7200
# Recall   : 0.3830
# F1 Score : 0.5000
# ROC-AUC  : 0.8119
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       247
#            1       0.72      0.38      0.50        47
#
#     accuracy                           0.88       294
#    macro avg       0.81      0.68      0.72       294
# weighted avg       0.86      0.88      0.86       294
#
#
# Confusion Matrix
# [[240   7]
#  [ 29  18]]

# %%
import numpy as np
from sklearn.metrics import recall_score, precision_score

thresholds = np.arange(0.1, 0.9, 0.05)

for t in thresholds:
    y_pred_thresh = (y_prob >= t).astype(int)
    recall = recall_score(y_test, y_pred_thresh)
    precision = precision_score(y_test, y_pred_thresh)
    print(f"Threshold: {t:.2f} | Recall: {recall:.3f} | Precision: {precision:.3f}")
# Out:
# Threshold: 0.10 | Recall: 0.745 | Precision: 0.310
# Threshold: 0.15 | Recall: 0.681 | Precision: 0.372
# Threshold: 0.20 | Recall: 0.638 | Precision: 0.429
# Threshold: 0.25 | Recall: 0.596 | Precision: 0.491
# Threshold: 0.30 | Recall: 0.553 | Precision: 0.531
# Threshold: 0.35 | Recall: 0.489 | Precision: 0.575
# Threshold: 0.40 | Recall: 0.468 | Precision: 0.647
# Threshold: 0.45 | Recall: 0.426 | Precision: 0.645
# Threshold: 0.50 | Recall: 0.383 | Precision: 0.720
# Threshold: 0.55 | Recall: 0.319 | Precision: 0.789
# Threshold: 0.60 | Recall: 0.255 | Precision: 0.800
# Threshold: 0.65 | Recall: 0.213 | Precision: 0.909
# Threshold: 0.70 | Recall: 0.191 | Precision: 0.900
# Threshold: 0.75 | Recall: 0.170 | Precision: 1.000
# Threshold: 0.80 | Recall: 0.128 | Precision: 1.000
# Threshold: 0.85 | Recall: 0.085 | Precision: 1.000

# %% [markdown]
# shap explainability

# %%
# !pip install shap
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    ---------------------------------------- 2/2 [shap]
#
# ...

# %%
import shap
best_model = grid.best_estimator_

preprocessor = best_model.named_steps['preprocessor']
feature_names = [] 
feature_names.extend(cont_cols)


cat_features = preprocessor.named_transformers_['nom'].get_feature_names_out(nominal_cols)
feature_names.extend(cat_features)

# %%
X_test_transformed = preprocessor.transform(X_test)

# %%
model = best_model.named_steps['model']

explainer = shap.LinearExplainer(
    model,
    X_test_transformed,
    feature_names=feature_names
)
# Out:
# Background dataset has 294 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=294 when initializing the masker.

# %%
shap_values = explainer.shap_values(X_test_transformed)

# For binary classification, take the positive class
if isinstance(shap_values, list):
    shap_values = shap_values[1]

# %%
plt.figure(figsize=(10, 8))
shap.summary_plot(shap_values, X_test_transformed, feature_names=feature_names, plot_type="bar")
plt.title("Feature Importance (SHAP)")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[146], line 2
#       1 plt.figure(figsize=(10, 8))
# ----> 2 shap.summary_plot(shap_values, X_test_transformed, feature_names=feature_names, plot_type="bar")
#       3 plt.title("Feature Importance (SHAP)")
#       4 plt.tight_layout()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\shap\plots\_beeswarm.py:1075, in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, use_log_scale, rng)
#    1073     plt.barh(y_pos, global_shap_values[feature_inds], 0.7, align="center", color=color)
#    1074     plt.yticks(y_pos, fontsize=13)
# -> 1075     plt.gca().set_yticklabels([feature_names[i] for i in feature_inds])
# ...

# %%
print("SHAP values shape:", shap_values.shape)
print("Transformed X shape:", X_test_transformed.shape)
print("Feature names:", len(feature_names))
# Out:
# SHAP values shape: (294, 51)
# Transformed X shape: (294, 51)
# Feature names: 42

# %%
import shap

best_model = grid.best_estimator_

preprocessor = best_model.named_steps['preprocessor']
model = best_model.named_steps['model']

# ✅ Get feature names automatically
feature_names = preprocessor.get_feature_names_out()

# ✅ Transform test set
X_test_transformed = preprocessor.transform(X_test)

# ✅ Create SHAP explainer
explainer = shap.LinearExplainer(model, X_test_transformed)

# ✅ Compute SHAP values
shap_values = explainer.shap_values(X_test_transformed)

# ✅ Plot
shap.summary_plot(shap_values, X_test_transformed, feature_names=feature_names)
# Out:
# Background dataset has 294 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=294 when initializing the masker.

# %%
import shap
import matplotlib.pyplot as plt

# Create figure
plt.figure(figsize=(10, 8))

shap.summary_plot(
    shap_values,
    X_test_transformed,
    feature_names=feature_names,
    plot_type="bar",
    show=False  # Important: prevents auto-display
)

plt.tight_layout()
plt.savefig("shap_bar_plot.png", dpi=300, bbox_inches='tight')
plt.close()

# %%
plt.figure(figsize=(10, 8))

shap.summary_plot(
    shap_values,
    X_test_transformed,
    feature_names=feature_names,
    show=False
)

plt.tight_layout()
plt.savefig("shap_beeswarm_plot.png", dpi=300, bbox_inches='tight')
plt.close()

# %%
# Final model with chosen hyperparameters
final_model = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(
        penalty='elasticnet',
        solver='saga',
        C=1,
        l1_ratio=0.75,
        max_iter=5000
    ))
])

final_model.fit(X_train, y_train)

# Save threshold manually (example: 0.20)
final_threshold = 0.20

# %%
import joblib

joblib.dump(final_model, "elasticnet_attrition_model.pkl")
joblib.dump(final_threshold, "decision_threshold.pkl")
# Out:
# ['decision_threshold.pkl']
